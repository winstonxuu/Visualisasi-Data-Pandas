# %% [markdown]
# # Week 12 - Memadukan loc dan Iloc untuk melakukan seleksi data

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.4.4

# %%
df = pd.read_csv('titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
df.iloc[15:20, :].loc[:, 'name':'age']
# Out:
#                                                name     sex   age
# 15                              Baumann, Mr. John D    male   NaN
# 16                         Baxter, Mr. Quigg Edmond    male  24.0
# 17  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18                            Bazzani, Miss. Albina  female  32.0
# 19                             Beattie, Mr. Thomson    male  36.0

# %%
df.loc[:, 'name':'age'].iloc[15:20, :]
# Out:
#                                                name     sex   age
# 15                              Baumann, Mr. John D    male   NaN
# 16                         Baxter, Mr. Quigg Edmond    male  24.0
# 17  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18                            Bazzani, Miss. Albina  female  32.0
# 19                             Beattie, Mr. Thomson    male  36.0

# %% [markdown]
# # Week 12 - Seleksi Weekdays dan Weekends pada data deret waktu (time series)

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.4.4
# 1.21.5

# %%
n_rows = 365
n_cols = 2
cols = ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)

df.index = pd.util.testing.makeDateIndex(n_rows, freq='D')
df
# Out:
# C:\Users\winst\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#             col1  col2
# 2000-01-01    13     7
# 2000-01-02     3     4
# 2000-01-03    15    14
# 2000-01-04     8     9
# 2000-01-05    18     7
# ...          ...   ...
# 2000-12-26     4     7
# 2000-12-27    19     2
# 2000-12-28     3    17
# 2000-12-29     6     4
# 2000-12-30     9    16
#
# [365 rows x 2 columns]

# %%
weekdays_df = df[df.index.dayofweek.isin([0, 1, 2, 3, 4])]
weekdays_df.head(7)
# Out:
#             col1  col2
# 2000-01-03    15    14
# 2000-01-04     8     9
# 2000-01-05    18     7
# 2000-01-06     1    10
# 2000-01-07     2    19
# 2000-01-10    10    14
# 2000-01-11    18     4

# %%
weekends_df = df[df.index.dayofweek.isin([5, 6])]
weekends_df.head(7)
# Out:
#             col1  col2
# 2000-01-01    13     7
# 2000-01-02     3     4
# 2000-01-08     6     2
# 2000-01-09    19    14
# 2000-01-15     6    10
# 2000-01-16    13     1
# 2000-01-22    18    12

# %% [markdown]
# # Week 12 - Deteksi dan penanganan kolom dengan tipe data beragam (mixed data types)

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.4.4

# %%
d = {'nama':['bejo', 'tejo', 'wati', 'tiwi', 'cecep'], 
     'ipk':[2, '3', 3, 2.75, '3.25']}
df = pd.DataFrame(d)
df
# Out:
#     nama   ipk
# 0   bejo     2
# 1   tejo     3
# 2   wati     3
# 3   tiwi  2.75
# 4  cecep  3.25

# %%
df.dtypes
# Out:
# nama    object
# ipk     object
# dtype: object

# %%
df['ipk'].apply(type)
# Out:
# 0      <class 'int'>
# 1      <class 'str'>
# 2      <class 'int'>
# 3    <class 'float'>
# 4      <class 'str'>
# Name: ipk, dtype: object

# %%
df['ipk'].apply(type).value_counts()
# Out:
# <class 'int'>      2
# <class 'str'>      2
# <class 'float'>    1
# Name: ipk, dtype: int64

# %%
df['ipk'] = df['ipk'].astype(float)

# %%
df['ipk'].apply(type).value_counts()
# Out:
# <class 'float'>    5
# Name: ipk, dtype: int64

# %% [markdown]
# # Week 12 - Mengenal Cummulative Count dengan cumcount()

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.4.4

# %%
d = {'penjual':['bejo', 'tejo', 'wati', 'bejo', 'cecep', 'tejo', 'wati', 'bejo'], 
     'barang':['monitor', 'monitor', 'keyboard', 'mouse', 'keyboard', 'monitor', 'laptop', 'monitor']}

df = pd.DataFrame(d)
df
# Out:
#   penjual    barang
# 0    bejo   monitor
# 1    tejo   monitor
# 2    wati  keyboard
# 3    bejo     mouse
# 4   cecep  keyboard
# 5    tejo   monitor
# 6    wati    laptop
# 7    bejo   monitor

# %%
df['count_tiap_penjual'] = df.groupby('penjual').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual
# 0    bejo   monitor                   1
# 1    tejo   monitor                   1
# 2    wati  keyboard                   1
# 3    bejo     mouse                   2
# 4   cecep  keyboard                   1
# 5    tejo   monitor                   2
# 6    wati    laptop                   2
# 7    bejo   monitor                   3

# %%
df['count_tiap_barang'] = df.groupby('barang').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang
# 0    bejo   monitor                   1                  1
# 1    tejo   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5    tejo   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4

# %%
df['count_pasangan_kolom'] = df.groupby(['penjual', 'barang']).cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang  \
# 0    bejo   monitor                   1                  1
# 1    tejo   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5    tejo   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4
#
#    count_pasangan_kolom
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# 5                     2
# 6                     1
# 7                     2
